# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %% [markdown]
# # 벡터
#
# ### 1. 선형대수학
# - 행렬과 벡터를 사용해 수많은 데이터를 한 번에 묶어 계산을 쉽게 도와줌
# - 묶인 데이터의 고유 특징들을 알려줌으로써 겉으로 보기 힘든 다양한 특성들을 분석할 수 있게 함
#
# ### 2. 스칼라와 벡터
# - **스칼라(scalar)**: 크기만 있고 방향은 가지지 않는 정보
# - **벡터(vector)**: 크기와 방향을 갖는 정보
#
# ##### <예제 1> 벡터 출력
# - x축과 y축 2차원 공간에서 A(붉은선), B(파란선), C(초록선) 벡터를 생성하고 시각화

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# A,B,C 벡터 정의
A = np.array([2,2])
B = np.array([-1,3])
C = np.array([5,2])
origin = [0], [0] # 원점

# 출력 파트
plt.quiver(*origin, [A[0],B[0],C[0]], [A[1],B[1],C[1]], color=['r','b','g'], angles='xy', scale_units='xy',scale=1)
plt.axis([-6,6,-6,6])
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9c90d467e1ff> in <cell line: 12>()
#      10
#      11 # 출력 파트
# ---> 12 plt.quiver(*origin, [A[0],B[0],C[0]], [A[1],B[1],C[1]], color=['r','b','g'], angles='xy', scale_units='xy',scale=1)
#      13 plt.axis([-6,6,-6,6])
#      14 plt.grid(True)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in quiver(data, *args, **kwargs)
#    2841 @_copy_docstring_and_deprecators(Axes.quiver)
#    2842 def quiver(*args, data=None, **kwargs):
# -> 2843     __ret = gca().quiver(
#    2844         *args, **({"data": data} if data is not None else {}),
#    2845         **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in quiver(self, *args, **kwargs)
#    5165         # Make sure units are handled for x and y values
#    5166         args = self._quiver_units(args, kwargs)
# -> 5167         q = mquiver.Quiver(self, *args, **kwargs)
#    5168         self.add_collection(q, autolim=True)
#    5169         self._request_autoscale_view()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/quiver.py in __init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kwargs)
#     503                          closed=False, **kwargs)
#     504         self.polykw = kwargs
# --> 505         self.set_UVC(U, V, C)
#     506         self._dpi_at_last_init = None
#     507
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/quiver.py in set_UVC(self, U, V, C)
#     553         for name, var in zip(('U', 'V', 'C'), (U, V, C)):
#     554             if not (var is None or var.size == self.N or var.size == 1):
# --> 555                 raise ValueError(f'Argument {name} has a size {var.size}'
#     556                                  f' which does not match {self.N},'
#     557                                  ' the number of arrow positions')
#
# ValueError: Argument U has a size 3 which does not match 1, the number of arrow positions

# %% [markdown]
# ##### 벡터의 크기
